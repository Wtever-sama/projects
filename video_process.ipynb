# %% [markdown]
# ### 使用协程，利用bh_videos_links.txt中提供的视频列表，进行对应视频文件（.mp4格式）的下载。

# %% [markdown]
# # 一
#
# 使用gevent + aiofiles 实现视频文件的下载，注意控制协程数目，避免服务器拒绝连接。

# %%
import gevent
from gevent import monkey
monkey.patch_all() # 打补丁，使得标准库异步化

import aiofiles
from geventhttpclient import httplib # geventhttpclient 是一个轻量级、高性能的 HTTP 客户端，适用于 gevent 环境
from geventhttpclient.client import HTTPClient
from geventhttpclient import client

import os
from urllib.parse import urlsplit # urlsplit() 函数用于将 URL 分解为各个组成部分

# %% [markdown]
# `fetch_video` 这是一个挨个从网上下载视频的函数

# %%
def fecth_video(url, output_path):
    try:
        parsed = urlsplit(url)
        http_client = client.HTTPClient(parsed.hostname, port=parsed.port, ssl=(parsed.scheme == 'https'))
        response = http_client.get(parsed.path + ('?'+ parsed.query if parsed.query else ''))
        if response.status_code == 200:
            with open(output_path, 'wb')as f:
                while True:
                    chunk = response.read(1024*1024) # 1MB
                    if not chunk:
                        break
                    f.write(chunk)
            print('音频保存至{}'.format(output_path))
        else:
            print(f'下载失败:{url}，状态码:{response.status_code}')
    except Exception as e:
        print(f'下载出错：{url},错误:{e}')

# %% [markdown]
# 从含有几百行url的 txt 文件里面将 URL 存储到数据结构里面

# %%
def get_url(file_path):
    with open(file_path,'r', encoding='utf-8')as f:
        url_ls = f.readlines()
    return url_ls

# %%
from gevent.pool import Pool

# %% [markdown]
# 协程处理的主函数
# - 如果文件不存在就下载视频
# - 存在就skip
# ---
# 所以就看到输出中有很多 skip，是因为多次调试和终端下载

# %%
def main(maxworkers):
    file_path = '/Users/wtsama/Documents/code/python文件大型/week13/bh_videos_links.txt'
    output_dir = '/Users/wtsama/Documents/code/python文件大型/week13/video/'
    url_ls = get_url(file_path)
    
    pool = Pool(size=maxworkers)
    tasks = []
    
    for i, url in enumerate(url_ls):
        filename = "video_{}.mp4".format(i)
        output_path = os.path.join(output_dir, filename)
        if  os.path.exists(output_path):
            print("{} exists, skip".format(output_path))
            continue
        task = pool.spawn(fecth_video, url, output_path)
        tasks.append(task)
    
    gevent.joinall(tasks)

# %%
if __name__ == '__main__':
    main(maxworkers=10)
# Out:
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_0.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_1.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_2.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_3.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_4.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_5.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_6.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_7.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_8.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_9.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_10.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_11.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_12.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_13.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_14.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_15.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_16.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_17.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_18.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_19.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_20.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_21.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_22.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_23.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_24.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_25.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_26.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_27.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_28.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_29.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_30.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_31.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_32.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_33.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_34.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_35.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_36.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_37.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_38.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_39.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_40.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_41.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_42.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_43.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_44.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_45.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_46.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_47.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_48.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_49.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_50.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_51.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_52.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_53.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_54.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_55.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_56.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_57.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_58.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_59.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_60.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_61.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_62.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_63.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_64.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_65.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_67.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_68.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_69.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_70.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_71.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_72.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_73.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_74.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_75.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_76.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_77.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_78.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_79.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_80.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_81.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_82.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_83.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_84.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_85.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_86.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_87.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_88.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_89.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_90.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_91.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_92.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_93.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_94.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_95.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_96.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_97.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_98.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_99.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_100.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_101.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_102.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_103.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_104.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_105.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_106.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_107.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_108.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_109.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_110.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_111.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_112.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_113.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_114.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_115.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_116.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_117.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_118.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_119.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_120.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_121.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_122.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_123.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_124.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_125.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_126.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_127.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_128.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_129.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_130.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_131.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_132.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_133.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_134.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_135.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_136.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_137.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_138.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_139.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_140.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_141.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_142.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_143.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_144.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_145.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_146.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_147.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_148.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_149.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_150.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_151.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_152.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_153.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_154.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_155.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_156.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_157.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_158.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_159.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_160.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_161.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_162.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_163.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_164.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_165.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_166.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_167.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_168.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_169.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_170.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_171.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_172.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_173.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_174.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_175.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_176.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_177.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_178.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_179.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_180.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_181.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_182.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_183.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_184.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_185.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_186.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_187.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_188.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_189.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_190.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_191.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_192.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_193.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_194.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_195.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_196.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_197.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_198.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_199.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_200.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_201.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_202.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_203.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_204.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_205.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_206.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_207.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_208.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_209.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_210.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_211.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_212.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_213.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_214.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_215.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_216.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_217.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_218.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_219.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_220.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_221.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_222.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_223.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_224.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_225.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_226.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_227.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_228.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_229.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_230.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_231.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_232.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_233.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_234.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_235.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_236.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_237.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_238.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_239.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_240.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_241.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_242.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_243.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_244.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_245.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_246.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_247.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_248.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_249.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_250.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_251.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_252.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_253.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_254.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_255.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_256.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_257.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_258.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_259.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_260.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_261.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_262.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_263.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_264.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_265.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_266.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_267.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_268.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_269.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_270.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_271.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_272.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_273.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_274.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_275.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_276.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_277.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_278.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_279.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_280.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_281.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_282.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_283.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_284.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_285.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_286.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_287.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_288.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_289.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_290.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_291.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_292.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_293.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_294.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_295.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_296.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_297.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_298.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_299.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_300.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_301.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_302.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_303.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_304.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_305.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_306.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_307.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_308.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_309.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_310.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_311.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_312.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_313.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_314.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_315.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_316.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_317.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_318.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_319.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_320.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_321.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_322.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_323.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_324.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_325.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_326.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_327.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_328.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_329.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_330.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_331.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_332.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_333.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_334.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_335.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_336.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_337.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_338.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_339.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_340.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_341.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_342.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_343.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_344.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_345.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_346.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_347.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_348.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_349.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_350.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_351.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_352.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_353.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_354.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_355.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_356.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_357.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_358.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_359.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_360.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_361.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_362.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_363.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_364.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_365.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_366.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_367.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_368.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_369.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_370.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_371.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_372.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_373.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_374.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_375.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_376.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_377.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_378.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_379.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_380.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_381.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_382.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_383.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_384.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_385.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_386.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_387.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_388.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_389.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_390.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_391.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_392.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_393.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_394.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_395.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_396.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_397.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_398.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_399.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_400.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_401.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_402.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_403.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_404.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_405.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_406.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_407.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_408.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_409.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_410.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_411.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_412.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_413.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_414.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_415.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_416.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_417.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_418.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_419.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_420.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_421.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_422.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_423.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_424.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_425.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_426.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_427.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_428.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_429.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_430.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_431.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_432.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_433.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_434.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_435.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_436.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_437.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_438.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_439.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_440.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_441.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_442.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_443.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_444.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_445.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_446.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_447.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_448.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_449.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_450.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_451.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_452.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_453.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_454.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_455.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_456.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_457.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_458.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_459.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_460.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_461.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_462.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_463.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_464.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_465.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_466.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_467.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_468.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_469.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_470.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_471.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_472.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_473.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_474.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_475.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_476.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_477.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_478.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_479.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_480.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_481.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_482.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_483.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_484.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_485.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_486.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_487.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_488.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_489.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_490.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_491.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_492.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_493.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_494.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_495.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_496.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_497.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_498.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_499.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_500.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_501.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_502.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_503.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_504.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_505.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_506.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_507.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_508.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_509.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_510.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_511.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_512.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_513.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_514.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_515.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_516.mp4 exists, skip
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_517.mp4 exists, skip
# 下载出错：https://news.buaa.edu.cnhttp://rmt.buaa.edu.cn/cm-sites-pms/storage/DD4EEDA1005273A6AFD0CA9EFE344207?.mp4
# ,错误:[Errno 8] nodename nor servname provided, or not known

# %% [markdown]
# # 二
#
# 使用aiohttp + aiofiles 实现视频文件的下载，注意控制协程数目，避免服务器拒绝连接。
#
# 注意文件有 518个

# %%
import aiohttp
import aiofiles
import asyncio
import os
from urllib.parse import urlsplit

import nest_asyncio
nest_asyncio.apply()

# %% [markdown]
# 因为要调用async 而不是 gevent所以`fetch_video`写法有点变化

# %%
async def fetch_video2(session, url, output_file):
    try:
        async with session.get(url) as response:
            if response.status == 200:
                async with aiofiles.open(output_file, 'wb')as f:
                    async for chunk in response.content.iter_chunked(1024*1024):
                        await f.write(chunk)
                print('下载完成，保存到{}'.format(output_file))
            else:
                print('下载失败，状态码{}'.format(response.status))
    except Exception as e:
        print('下载失败，{}'.format(e))

# %%
def get_url_list(file_path):
    with open(file_path, 'r', encoding = 'utf-8') as f:
        return f.readlines()

# %% [markdown]
# 调用`aiohttp`的主函数

# %%
async def main_async(maxworkers):
    file_path = '/Users/wtsama/Documents/code/python文件大型/week13/bh_videos_links.txt'
    output_dir = '/Users/wtsama/Documents/code/python文件大型/week13/video2/'
    url_ls = get_url_list(file_path)
    
    connector = aiohttp.TCPConnector(limit_per_host=10,ssl=False)
    semaphore = asyncio.Semaphore(maxworkers)
    
    async def limited_download(session, url, output_path):
        async with semaphore:
            await fetch_video2(session, url, output_path)
    
    async with aiohttp.ClientSession(connector=connector) as session:
        tasks = []
        for idx, url in enumerate(url_ls):
            filename = f'video_{idx}.mp4'
            if os.path.exists(os.path.join(output_dir, filename)):
                print(f'{filename} exists, skip')
                continue    
            task = asyncio.create_task(
                fetch_video2(session, url, os.path.join(output_dir, filename)))
            tasks.append(task)
        await asyncio.gather(*tasks)

# %% [markdown]
# 这里已经运行通了，就不重复下载了；报错是因为手动停止

# %%
if __name__ == '__main__':
    asyncio.run(main_async(maxworkers=10))
# Out:
# /opt/anaconda3/envs/myenv2/lib/python3.12/site-packages/aiohttp/client.py:1424: RuntimeWarning: coroutine 'main_async' was never awaited
#   async def __aenter__(self) -> _RetType:
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# 下载失败，Cannot connect to host news.buaa.edu.cnhttp:443 ssl:default [nodename nor servname provided, or not known]
# 下载完成，保存到/Users/wtsama/Documents/code/python文件大型/week13/video2/video_0.mp4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 2
#       1 if __name__ == '__main__':
# ----> 2     asyncio.run(main_async(maxworkers=10))
#
# File /opt/anaconda3/envs/myenv2/lib/python3.12/site-packages/nest_asyncio.py:30, in _patch_asyncio.<locals>.run(main, debug)
#      28 task = asyncio.ensure_future(main)
#      29 try:
# ---> 30     return loop.run_until_complete(task)
#      31 finally:
#      32     if not task.done():
#
# File /opt/anaconda3/envs/myenv2/lib/python3.12/site-packages/nest_asyncio.py:92, in _patch_loop.<locals>.run_until_complete(self, future)
#      90     f._log_destroy_pending = False
#      91 while not f.done():
# ---> 92     self._run_once()
#      93     if self._stopping:
#      94         break
#
# File /opt/anaconda3/envs/myenv2/lib/python3.12/site-packages/nest_asyncio.py:115, in _patch_loop.<locals>._run_once(self)
#     108     heappop(scheduled)
#     110 timeout = (
#     111     0 if ready or self._stopping
#     112     else min(max(
#     113         scheduled[0]._when - self.time(), 0), 86400) if scheduled
#     114     else None)
# --> 115 event_list = self._selector.select(timeout)
#     116 self._process_events(event_list)
#     118 end_time = self.time() + self._clock_resolution
#
# File /opt/anaconda3/envs/myenv2/lib/python3.12/selectors.py:566, in KqueueSelector.select(self, timeout)
#     564 ready = []
#     565 try:
# --> 566     kev_list = self._selector.control(None, max_ev, timeout)
#     567 except InterruptedError:
#     568     return ready
#
# KeyboardInterrupt:

# %% [markdown]
# # 三
#
# 利用ffmpeg，获取所有视频文件的长度信息，并进行长度分布的可视化。

# %%
from ffmpy import FFmpeg

import subprocess
import json

# %%
def get_video_info(video_path):
    if not os.path.exists(video_path) or os.path.getsize(video_path) == 0:
        print(f"文件不存在或为空: {video_path}")
        return None
    
    cmd = [
            'ffprobe',  # ffprobe工具路径
            '-v', 'error',  # 只显示错误信息，减少输出的冗余
            '-print_format', 'json',  # 输出格式设置为JSON，便于解析
            '-show_format',  # 显示文件格式信息
            '-show_streams',  # 显示文件流信息
            video_path  # 需要分析的音视频文件路径
        ]
    try:
        # 运行 ffprobe 命令并捕获其输出结果。
        
        result = subprocess.run(cmd, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True, check=True)
        info = json.loads(result.stdout)
        return info['format']['duration'] # str， 需要用float()转成float类型
    except subprocess.CalledProcessError as e:
        print("ffprobe 出错:", e.stderr)
        return None

# %% [markdown]
# 用`concurrent.futures`模块的`ThreadPoolExecutor`类创建一个线程池便于得到结果进行后续操作。

# %%
from concurrent.futures import ThreadPoolExecutor
import os 
import sys

from pathlib import Path
import math

# %% [markdown]
# 多线程分块进行

# %%
def process_chunk(chunk_lst):
    res = []
    for path in chunk_lst:
        filename = os.path.basename(path)
        filename = os.path.splitext(filename)[0]
        if not get_video_info(path):
            print('跳过无效文件{}'.format(path))
            continue
        res.append((filename, float(get_video_info(path))))
    return res

# %%
def slice_lst(lst, num_process):
    start = 0
    reminder = len(lst)%num_process
    chunk_size=math.ceil(len(lst)/num_process)
    threads=[]
    for i in range(num_process):
        end = start+chunk_size +(1 if reminder>i else 0)
        threads.append(lst[start:end])
        start=end
    return threads

# %% [markdown]
# 这个函数 `process_all` 运行时间很久，大概 2、3 分钟

# %%
def process_all(dir_path, num_parts):
    dir_path = Path(dir_path)
    video_lst = []
    for f in dir_path.rglob('*.mp4'): # rglob('*') 递归匹配所有文件
        video_lst.append(str(f)) # 都是绝对路径
    chunk_lst = slice_lst(video_lst, num_parts)
    
    with ThreadPoolExecutor() as executor:
        futures = [executor.submit(process_chunk, part) for part in chunk_lst]
        # 接受所有结果
        results = []
        for future in futures:
            results.extend(future.result())
    print('************************************************\n')
    print('一共找到{}个有效视频文件'.format(len(results)))
    return results

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# 画图，横轴是视频，纵轴是持续时间，柱状

# %%
def draw(res):
    xs =[]
    ys =[]
    for item in res:
        xs.append(item[0])
        ys.append(item[1])
    max_y = max(ys)
    min_y = min(ys)
    
    if not ys:
        print('没有可以画图的数据')
    # mac系统中中文字体路径
    plt.bar(xs, ys, color = 'red')
    plt.ylim(min_y-0.5, max_y+0.5)
    plt.xlabel('video name')
    plt.ylabel('duration(s)')
    plt.title('{} videos and duration distribution'.format(len(res)))
    plt.xticks(rotation=90)
    
    plt.savefig('{} videos and duration distribution.png'.format(len(res)))
    plt.show()

# %% [markdown]
# 第三题的主函数

# %%
def main2():
    dir_path = '/Users/wtsama/Documents/code/python文件大型/week13/video/'
    num_parts = 10
    res = process_all(dir_path, num_parts)
    print('用于绘图的视频和长度:',res)
    draw(res)

# %% [markdown]
# - 这里运行结果，发现有 15 个文件有问题，文件得不到重要信息，就跳过了，有可能是下载的过程中出现了问题（网络不太好）；看似报错实际上是因为添加了异常处理，运行过程是跑通了的。
# - 将得到的 503 个文件进行了绘图。图片x轴是一片黑是因为文字太密集了，后面我们单独统计文件长度信息。

# %%
if __name__=="__main__":
    main2()
# Out:
# ffprobe 出错: [mov,mp4,m4a,3gp,3g2,mj2 @ 0x7f95b440a200] moov atom not found
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_517.mp4: Invalid data found when processing input
#
# 跳过无效文件/Users/wtsama/Documents/code/python文件大型/week13/video/video_517.mp4
# ffprobe 出错: [mov,mp4,m4a,3gp,3g2,mj2 @ 0x7fbeafc07900] moov atom not found
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_513.mp4: Invalid data found when processing input
#
# 跳过无效文件/Users/wtsama/Documents/code/python文件大型/week13/video/video_513.mp4
# ffprobe 出错: [mov,mp4,m4a,3gp,3g2,mj2 @ 0x7f87968058c0] moov atom not found
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_333.mp4: Invalid data found when processing input
#
# 跳过无效文件/Users/wtsama/Documents/code/python文件大型/week13/video/video_333.mp4
# ffprobe 出错: [mov,mp4,m4a,3gp,3g2,mj2 @ 0x7f8ea0a09940] moov atom not found
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_337.mp4: Invalid data found when processing input
#
# 跳过无效文件/Users/wtsama/Documents/code/python文件大型/week13/video/video_337.mp4
# ffprobe 出错: [mov,mp4,m4a,3gp,3g2,mj2 @ 0x7fb0f9b09fc0] moov atom not found
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_335.mp4: Invalid data found when processing input
#
# 跳过无效文件/Users/wtsama/Documents/code/python文件大型/week13/video/video_335.mp4
# ffprobe 出错: [mov,mp4,m4a,3gp,3g2,mj2 @ 0x7fa100f16740] stream 1, contradictionary STSC and STCO
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x7fa100f16740] error reading header
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_137.mp4: Invalid data found when processing input
#
# 跳过无效文件/Users/wtsama/Documents/code/python文件大型/week13/video/video_137.mp4
# ffprobe 出错: [mov,mp4,m4a,3gp,3g2,mj2 @ 0x7ff022a173c0] moov atom not found
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_332.mp4: Invalid data found when processing input
#
# 跳过无效文件/Users/wtsama/Documents/code/python文件大型/week13/video/video_332.mp4
# ffprobe 出错: [mov,mp4,m4a,3gp,3g2,mj2 @ 0x7f89a2a06e00] moov atom not found
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_338.mp4: Invalid data found when processing input
#
# 跳过无效文件/Users/wtsama/Documents/code/python文件大型/week13/video/video_338.mp4
# ffprobe 出错: [mov,mp4,m4a,3gp,3g2,mj2 @ 0x7feebf80ea40] stream 1, contradictionary STSC and STCO
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x7feebf80ea40] error reading header
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_35.mp4: Invalid data found when processing input
#
# 跳过无效文件/Users/wtsama/Documents/code/python文件大型/week13/video/video_35.mp4
# ffprobe 出错: [mov,mp4,m4a,3gp,3g2,mj2 @ 0x7fce3d90f640] stream 1, contradictionary STSC and STCO
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x7fce3d90f640] error reading header
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_138.mp4: Invalid data found when processing input
#
# 跳过无效文件/Users/wtsama/Documents/code/python文件大型/week13/video/video_138.mp4
# ffprobe 出错: [mov,mp4,m4a,3gp,3g2,mj2 @ 0x7fdf0c217d00] moov atom not found
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_334.mp4: Invalid data found when processing input
#
# 跳过无效文件/Users/wtsama/Documents/code/python文件大型/week13/video/video_334.mp4
# ffprobe 出错: [mov,mp4,m4a,3gp,3g2,mj2 @ 0x7fec58a0e0c0] moov atom not found
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_152.mp4: Invalid data found when processing input
#
# 跳过无效文件/Users/wtsama/Documents/code/python文件大型/week13/video/video_152.mp4
# ffprobe 出错: [mov,mp4,m4a,3gp,3g2,mj2 @ 0x7fd85ef0ef00] moov atom not found
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_515.mp4: Invalid data found when processing input
#
# 跳过无效文件/Users/wtsama/Documents/code/python文件大型/week13/video/video_515.mp4
# 文件不存在或为空: /Users/wtsama/Documents/code/python文件大型/week13/video/video_61.mp4
# 跳过无效文件/Users/wtsama/Documents/code/python文件大型/week13/video/video_61.mp4
# ************************************************
#
# 一共找到503个有效视频文件
# 用于绘图的视频和长度: [('video_509', 109.568), ('video_253', 252.64), ('video_247', 475.08), ('video_290', 290.946009), ('video_284', 105.418005), ('video_469', 855.52), ('video_441', 858.68), ('video_327', 869.930667), ('video_455', 282.96), ('video_482', 1095.354921), ('video_496', 68.56), ('video_119', 190.96), ('video_125', 303.0), ('video_131', 93.64), ('video_38', 1076.608), ('video_10', 137.92), ('video_11', 271.84), ('video_39', 1383.808), ('video_130', 227.882), ('video_124', 158.52), ('video_118', 238.92), ('video_497', 667.76), ('video_483', 269.6), ('video_454', 926.208), ('video_440', 428.629333), ('video_326', 922.602667), ('video_468', 209.44), ('video_285', 160.56), ('video_291', 244.28), ('video_246', 284.36), ('video_252', 116.44), ('video_508', 2028.32), ('video_278', 580.76), ('video_244', 351.84), ('video_250', 222.56), ('video_287', 431.055011), ('video_293', 443.221995), ('video_318', 219.16), ('video_456', 427.32), ('video_330', 712.3), ('video_324', 1195.008), ('video_442', 1239.12), ('video_495', 882.56), ('video_481', 1296.393288), ('video_132', 88.24), ('video_126', 326.64), ('video_13', 286.767007), ('video_12', 223.488), ('video_127', 175.04), ('video_133', 241.96), ('video_480', 545.08), ('video_494', 379.498667), ('video_325', 1111.530667), ('video_443', 788.52), ('video_457', 1074.72), ('video_331', 607.596553), ('video_319', 552.28), ('video_292', 547.2), ('video_286', 339.64), ('video_251', 171.2), ('video_245', 581.44), ('video_279', 1128.64), ('video_241', 242.88), ('video_255', 407.719002), ('video_269', 180.053), ('video_282', 295.88), ('video_296', 254.44), ('video_453', 907.56), ('video_447', 592.08), ('video_321', 492.16), ('video_309', 384.0), ('video_490', 110.016), ('video_484', 638.4), ('video_123', 297.44), ('video_16', 708.36), ('video_17', 156.36), ('video_122', 282.24), ('video_136', 281.84), ('video_485', 710.4), ('video_491', 123.92), ('video_308', 252.522667), ('video_446', 266.2), ('video_320', 512.4), ('video_452', 907.6), ('video_297', 312.48), ('video_283', 206.96), ('video_268', 154.946009), ('video_254', 205.2), ('video_240', 269.28), ('video_256', 229.68), ('video_242', 60.073), ('video_295', 113.44), ('video_281', 165.0), ('video_322', 577.64), ('video_8', 401.76), ('video_444', 895.4), ('video_450', 674.88), ('video_336', 199.36), ('video_478', 270.0), ('video_487', 423.56), ('video_493', 404.906667), ('video_120', 370.64), ('video_134', 154.8), ('video_108', 488.92), ('video_15', 396.566667), ('video_29', 342.28), ('video_28', 237.68), ('video_14', 204.52), ('video_109', 139.72), ('video_135', 111.2), ('video_121', 322.56), ('video_492', 710.890667), ('video_486', 299.64), ('video_479', 739.6), ('video_451', 1069.04), ('video_323', 244.96), ('video_445', 967.8), ('video_9', 227.32), ('video_280', 236.64), ('video_294', 96.618005), ('video_243', 297.4), ('video_257', 288.0), ('video_218', 197.76), ('video_230', 236.44), ('video_224', 404.468005), ('video_378', 333.64), ('video_344', 1061.72), ('video_422', 1009.16), ('video_436', 689.48), ('video_350', 389.482667), ('video_387', 347.44), ('video_393', 780.96), ('video_98', 204.56), ('video_146', 184.04), ('video_73', 328.24), ('video_185', 274.878005), ('video_191', 319.16), ('video_67', 435.75), ('video_190', 133.72), ('video_72', 128.44), ('video_184', 419.8), ('video_153', 159.450998), ('video_147', 300.04), ('video_99', 198.2), ('video_392', 788.28), ('video_386', 926.56), ('video_437', 430.6), ('video_351', 268.88), ('video_345', 990.2), ('video_423', 354.858667), ('video_379', 450.2), ('video_225', 405.44), ('video_231', 191.44), ('video_219', 319.12), ('video_227', 152.2), ('video_233', 259.84), ('video_409', 875.2), ('video_353', 450.2), ('video_435', 328.682667), ('video_421', 554.84), ('video_347', 924.0), ('video_390', 1000.52), ('video_384', 672.84), ('video_179', 202.107007), ('video_151', 189.44), ('video_145', 1295.765), ('video_58', 95.84), ('video_64', 209.24), ('video_192', 351.92), ('video_186', 454.28), (' ...

# %% [markdown]
# # 四
#
# 参考ali_video.py，选择少量的长度较短的视频（10个左右），利用视觉大模型进行视频内容的理解；根据输出的文本，进一步利用大模型（如deepseek)进一步总结所采集视频的主题有哪些。

# %% [markdown]
# 避免多次调用process_all处理结果

# %%
def cache_results(dir_path):
    res = process_all(dir_path, num_parts=10)
    with open('cache.py', 'w', encoding='utf-8')as f:
        f.write(f'res={res}')
    print('results of process_all saved to cache.py')

# %%
cache_results('/Users/wtsama/Documents/code/python文件大型/week13/video/')
# Out:
# ffprobe 出错: [mov,mp4,m4a,3gp,3g2,mj2 @ 0x7fc79ea0ddc0] moov atom not found
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_517.mp4: Invalid data found when processing input
#
# 跳过无效文件/Users/wtsama/Documents/code/python文件大型/week13/video/video_517.mp4
# ffprobe 出错: [mov,mp4,m4a,3gp,3g2,mj2 @ 0x7fa368904f00] moov atom not found
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_513.mp4: Invalid data found when processing input
#
# 跳过无效文件/Users/wtsama/Documents/code/python文件大型/week13/video/video_513.mp4
# ffprobe 出错: [mov,mp4,m4a,3gp,3g2,mj2 @ 0x7fd8987064c0] moov atom not found
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_333.mp4: Invalid data found when processing input
#
# 跳过无效文件/Users/wtsama/Documents/code/python文件大型/week13/video/video_333.mp4
# ffprobe 出错: [mov,mp4,m4a,3gp,3g2,mj2 @ 0x7f80037057c0] moov atom not found
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_337.mp4: Invalid data found when processing input
#
# 跳过无效文件/Users/wtsama/Documents/code/python文件大型/week13/video/video_337.mp4
# ffprobe 出错: [mov,mp4,m4a,3gp,3g2,mj2 @ 0x7ff4f3804900] moov atom not found
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_335.mp4: Invalid data found when processing input
#
# 跳过无效文件/Users/wtsama/Documents/code/python文件大型/week13/video/video_335.mp4
# ffprobe 出错: [mov,mp4,m4a,3gp,3g2,mj2 @ 0x7f9481006d40] stream 1, contradictionary STSC and STCO
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x7f9481006d40] error reading header
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_137.mp4: Invalid data found when processing input
#
# 跳过无效文件/Users/wtsama/Documents/code/python文件大型/week13/video/video_137.mp4
# ffprobe 出错: [mov,mp4,m4a,3gp,3g2,mj2 @ 0x7fd460c05600] moov atom not found
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_332.mp4: Invalid data found when processing input
#
# 跳过无效文件/Users/wtsama/Documents/code/python文件大型/week13/video/video_332.mp4
# ffprobe 出错: [mov,mp4,m4a,3gp,3g2,mj2 @ 0x7fe6d2105e00] moov atom not found
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_338.mp4: Invalid data found when processing input
#
# 跳过无效文件/Users/wtsama/Documents/code/python文件大型/week13/video/video_338.mp4
# ffprobe 出错: [mov,mp4,m4a,3gp,3g2,mj2 @ 0x7fe3a9a0cd40] stream 1, contradictionary STSC and STCO
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x7fe3a9a0cd40] error reading header
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_35.mp4: Invalid data found when processing input
#
# 跳过无效文件/Users/wtsama/Documents/code/python文件大型/week13/video/video_35.mp4
# ffprobe 出错: [mov,mp4,m4a,3gp,3g2,mj2 @ 0x7fa0d9018380] stream 1, contradictionary STSC and STCO
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x7fa0d9018380] error reading header
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_138.mp4: Invalid data found when processing input
#
# 跳过无效文件/Users/wtsama/Documents/code/python文件大型/week13/video/video_138.mp4
# ffprobe 出错: [mov,mp4,m4a,3gp,3g2,mj2 @ 0x7fc98e104400] moov atom not found
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_152.mp4: Invalid data found when processing input
#
# 跳过无效文件/Users/wtsama/Documents/code/python文件大型/week13/video/video_152.mp4
# ffprobe 出错: [mov,mp4,m4a,3gp,3g2,mj2 @ 0x7fcc6a009c80] moov atom not found
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_334.mp4: Invalid data found when processing input
#
# 跳过无效文件/Users/wtsama/Documents/code/python文件大型/week13/video/video_334.mp4
# 文件不存在或为空: /Users/wtsama/Documents/code/python文件大型/week13/video/video_61.mp4
# 跳过无效文件/Users/wtsama/Documents/code/python文件大型/week13/video/video_61.mp4
# ffprobe 出错: [mov,mp4,m4a,3gp,3g2,mj2 @ 0x7fec1e904900] moov atom not found
# /Users/wtsama/Documents/code/python文件大型/week13/video/video_515.mp4: Invalid data found when processing input
#
# 跳过无效文件/Users/wtsama/Documents/code/python文件大型/week13/video/video_515.mp4
# ************************************************
#
# 一共找到503个有效视频文件
# results of process_all saved to cache.py

# %% [markdown]
# - 由于变量results包含所有有效文件的长度信息和文件名称，所以为了避免每次调试加载就储存在`cache.py`文件中，作为模块调用
# - 由于视频大模型不能理解超长的视频，从第九长的视频就出错，选取了前八个

# %%
def sort_len(dir_path):
    '''
    获取前八个最短的视频'''
    if os.path.exists('cache.py'):
        from cache import res
        sorted_res = sorted(res, key = lambda x:x[1])
        min_8 = sorted_res[:8]
        print('min_8: ',min_8)
        return min_8
    return None

# %%
from dashscope import MultiModalConversation
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# 从`.env`文件中加载 `api_key`

# %%
api_key = os.getenv("DASHSCOPE_API_KEY")

# %% [markdown]
# 同样，由于每次调试都调用大模型很费事费钱，所以把输出一个一个存在一个文本里了，有八个文本。

# %%
def call_video_model(dir_path):
    '''
    调用视频模型理解每个视频
    参数：dir_path，第一题存储视频的文件路径
    返回：texts，所有视频的文字列表'''
    min_8 = sort_len(dir_path) if sort_len(dir_path) else 0
    texts =[]
    for item in min_8:
        file = item[0]
        file = file + '.mp4'
        file = os.path.join(dir_path, file)
        print('调用大模型理解视频-{}'.format(item[0]))
        message = [{'role': 'system',
                'content': [{'text': 'You are a helpful assistant.'}]},
                {'role':'user',
                # fps参数控制视频抽帧数量，表示每隔1/fps 秒抽取一帧
                # txt为指令
                'content': [{'video': file,"fps":2},
                            {'text': '详细描述视频内容。'}]}]
        response = MultiModalConversation.call(
        api_key = api_key,
        model = 'qwen-vl-max-latest',  
        messages = message)
        
        text = response["output"]["choices"][0]["message"].content[0]["text"]
        print('type of text: ',type(text))
        
        with open('{}.txt'.format(item[0]),'w',encoding='utf-8')as f:
            f.write(text)
        print('保存视频描述文件到{}.txt'.format(item[0]))
        
        file = item[0]
        texts.append(file+':'+text+'\n')
    
        
    return texts

# %% [markdown]
# 考虑到成本原则，就一次性调用直接存储了，没有进行封装，实际上是运行通过了的
# 见截图

# %%
dir_path = '/Users/wtsama/Documents/code/python文件大型/week13/video/'
texts = call_video_model(dir_path)

# %%
import os
from openai import OpenAI

# %% [markdown]
# 用deepseek进行理解输出的文本，一次性理解所有，总结主题

# %%
def call_deepseek(desciption):
    
    client = OpenAI(
        api_key=api_key,  # 如何获取API Key：https://help.aliyun.com/zh/model-studio/developer-reference/get-api-key
        base_url="https://dashscope.aliyuncs.com/compatible-mode/v1"
    )
    print('调用 ds 理解————')
    completion = client.chat.completions.create(
        model="deepseek-r1-distill-llama-70b",# 限时免费  # 此处以 deepseek-r1 为例，可按需更换模型名称。
        messages=[
            {'role': 'user', 'content': '请你帮我提取文本的主题，总结这些主题有哪些：{}'.format(desciption)}
        ]
    )

    # 通过reasoning_content字段打印思考过程
    print("思考过程：")
    print(completion.choices[0].message.reasoning_content)

    # 通过content字段打印最终答案
    print("最终答案：")
    print(completion.choices[0].message.content)

# %% [markdown]
# 这个函数`sum_themes`是将所有的文本理解加成成一个长字符串喂给 ds的,`dir_path`是视频的目录

# %%
def sum_themes(dir_path):
    sl = sort_len(dir_path)
    min_8 = sl if sl else 0
    texts = []
    for item in min_8:
        file = item[0]
        file_path = file+'.txt'
        with open(file_path, 'r', encoding='utf-8') as f:
            texts.append('{}的内容:'.format(item[0])+f.read()+'\n')
    print('输入视频的数量:',len(texts))
    return ''.join(texts)+'注意，输入的视频有{}个'.format(len(texts))

# %% [markdown]
# 一个主函数，对应第四题

# %%
def main4():
    dir_path = '/Users/wtsama/Documents/code/python文件大型/week13/video/'
    texts = sum_themes(dir_path)
    call_deepseek(texts)

# %%
if __name__ == '__main__':
    main4()
# Out:
# min_8:  [('video_4', 14.720998), ('video_46', 17.879002), ('video_0', 19.132993), ('video_48', 24.938005), ('video_467', 25.12), ('video_511', 26.56), ('video_3', 27.539002), ('video_500', 27.88)]
# 输入视频的数量: 8
# 调用 ds 理解————
# 思考过程：
# 嗯，我现在要帮用户提取文本中的主题，并总结这些主题。用户给了我8个视频的内容，每个视频都有详细的描述。我需要仔细阅读每个视频的内容，找出它们的主题，然后进行分类和总结。
#
# 首先，我来看看每个视频的基本信息：
#
# video_4：校园春天的美景，展示了九宫格照片、动态过渡、校园景色和结尾画面，突出北京航空航天大学的春天。
#
# video_46：拔河比赛，户外活动，参赛队伍、裁判、摄影师，比赛过程，团队精神和观众热情。
#
# video_0：姜铁红教授的专题讲座，在北航美育大讲堂，讲座内容是关于舞蹈《奔腾》的美学表达，现场教学和观众反应。
#
# video_48：校园体育活动，包括绕杆跑、跳高、平衡木、拔河、排球、接力赛、篮球、壶铃训练和集体活动，展示多样性和团队合作。
#
# video_467：月宫365实验，模拟封闭环境中的生存条件，展示实验舱内部、植物培养、日常生活、生命保障系统、健康监测和锻炼。
#
# video_511：创新创业大赛，在西安举行，会场环境、演讲与展示、具体内容、评委与嘉宾、氛围和媒体标识，突出科技创新。
#
# video_3：怀念老院长，通过海棠花的景象，回忆沈元老院长，展示海棠树的象征意义和北航的发展历史。
#
# video_500：中法工程师学院的企业开放日，致辞、观众反应、现场互动、学生表演和合影，促进中法合作。
#
# 接下来，我需要从每个视频中提取主题：
#
# video_4：校园春天、自然美景、北京航空航天大学。
#
# video_46：拔河比赛、团队精神、校园活动、体育竞技。
#
# video_0：舞蹈艺术、美育讲座、文化传承、姜铁红。
#
# video_48：校园体育、多样性活动、团队合作、青春活力。
#
# video_467：封闭生存实验、科学研究、月宫365、可持续生存。
#
# video_511：创新创业、科技比赛、教育活动、北航全球大赛。
#
# video_3：怀念、海棠花、沈元老院长、北航精神。
#
# video_500：中法合作、国际交流、企业开放日、教育合作。
#
# 然后，我需要将这些主题进行分类，看看是否有重复或相似的主题：
#
# 1. 校园活动：包括video_4、video_46、video_48，都是关于校园内的活动和景象。
#
# 2. 体育竞技：video_46、video_48，涉及拔河、接力赛、篮球等体育项目。
#
# 3. 教育与文化：video_0、video_3、video_500，涉及讲座、文化传承、国际合作。
#
# 4. 科技与创新：video_467、video_511，涉及科学实验和创新创业大赛。
#
# 5. 校园精神：video_3、video_4，涉及校园象征和精神传承。
#
# 6. 国际合作：video_500，涉及中法工程师学院的合作活动。
#
# 可能还需要进一步细化，比如将“教育与文化”拆分成“艺术教育”和“文化传承”等。但根据用户提供的示例，他们可能希望较高层次的分类。
#
# 总结起来，主题包括：
#
# - 校园活动与美景
# - 体育竞技与团队合作
# - 教育与文化活动
# - 科技与创新
# - 校园精神与传承
# - 国际合作与交流
#
# 这样分类后，每个主题下可以包含多个视频的内容，确保全面且有逻辑性。
# 最终答案：
# ### 提取的主题及总结
#
# 通过对多个视频内容的分析和提取，以下是主要主题及其总结：
#
# 1. **校园活动与美景**
#    - **视频**：video_4
#    - **主题**：展示校园春天的美丽景色，包括花坛、树木、绿地和建筑的和谐景象，突出北京航空航天大学的校园环境。
#
# 2. **体育竞技与团队合作**
#    - **视频**：video_46、video_48
#    - **主题**：记录拔河比赛和其他体育活动，展现团队精神、激烈竞争和观众热情，体现校园生活的活力。
#
# 3. **教育与文化活动**
#    - **视频**：video_0、video_3、video_500
#    - **主题**：涵盖专题讲座、文化传承和国际合作，展示教育活动的多样性和文化交流的重要性。
#
# 4. **科技与创新**
#    - **视频**：video_467、video_511
#    - **主题**：涉及科学实验和创新创业大赛，展示科技研究的深度和创新项目的多样性。
#
# 5. **校园精神与传承**
#    - **视频**：video_3、video_4
#    - **主题**：通过海棠花和校园景象，表达对老院长的怀念和校园精神的传承，强调历史与现实的联系。
#
# 6. **国际合作与交流**
#    - **视频**：video_500
#    - **主题**：展示中法工程师学院的合作活动，促进国际交流与教育合作，推动人才培养。
#
# ### 总结
#
# 这些主题涵盖了校园生活的多个方面，包括自然美景、体育活动、教育文化、科技创新、精神传承和国际合作。每个主题通过不同的视频内容得到了详细展示，共同构建了一个丰富多彩的校园及相关活动图景。
